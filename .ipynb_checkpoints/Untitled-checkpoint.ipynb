# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')
print(df.shape)
print(df.info())
df.tail(2)
# Out:
# (1025, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1023   50    0   0       110   254    0        0      159      0      0.0
# ...

# %%
#print(df.duplicated().any())
#df = df.drop_duplicates
#print(df.duplicated().any())
df.shape
# Out:
# (1025, 14)

# %%
df.corr()#corelsn
plt.figure(figsize=(14,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
print(df['target'].value_counts())
sns.countplot(x=df['target'])
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
sns.countplot(x=df['sex'])
plt.xticks([0,1],['F','M'])
plt.show()

# %%
sns.countplot(x="sex",hue="target",data=df)
plt.xticks([0,1],['F','M'])
plt.legend(['sick','well'])
plt.show()

# %%
sns.histplot(x=df['age'],kde=True,bins=30)
plt.show()

# %%
sns.countplot(x="cp",data=df)
plt.xticks(rotation=66)
plt.xticks([0,1,2,3],['typcl angil','atyp angina','non-aginl','asymptomtic'])
plt.show()

# %%
gf = sns.FacetGrid(df,hue='sex',aspect=3)
gf.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['male','femal'])

# %%
cont_var=[]
for col in df.columns:
    if df[col].nunique()>=11:
        cont_var.append(col)
    else : continue
print(cont_var)
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
df.hist(cont_var)
plt.show()
